# %% [markdown]
# ![Data Dunkers Banner](https://github.com/Data-Dunkers/lessons/blob/main/images/top-banner.jpg?raw=true)
#
# <a href="https://hub.callysto.ca/jupyter/hub/user-redirect/git-pull?repo=https%3A%2F%2Fgithub.com%2Fdata-dunkers%2Flessons&branch=main&subPath=data-from-excel.ipynb&depth=1" target="_parent"><img src="https://raw.githubusercontent.com/Data-Dunkers/lessons/main/images/open-in-callysto-button.svg?sanitize=true" width="123" height="24" alt="Open in Callysto"/></a><a href="https://colab.research.google.com/github/data-dunkers/lessons/blob/main/data-from-excel.ipynb" target="_parent"><img src="https://raw.githubusercontent.com/Data-Dunkers/lessons/main/images/open-in-colab-button.svg?sanitize=true" width="123" height="24" alt="Open in Colab"/></a>

# %% [markdown]
# # Getting Data from an Excel File

# %% [markdown]
# The corresponding Activity Notebook for this Lesson Notebook can be found [here](https://github.com/Data-Dunkers/activities/blob/main/data-from-excel.ipynb).

# %% [markdown]
# ## Lesson Objectives

# %% [markdown]
# By the end of this lesson, students will be able to:
# - Explore how to retrieve and plot data from an Excel file. *(Example: Load X and Y data from an Excel file and create a line plot to visualize the data.)*
# - Recognize the similarities and differences between working with CSV and Excel files. *(Example: Compare the process of loading X and Y data from a CSV file versus an Excel file and plotting the results.)*

# %% [markdown]
# ## Introduction

# %% [markdown]
# There are many ways we can import data, but the most common are from the program itself, a CSV (comma separated values) file, from an Excel spreadsheet, from a Google Sheet, or from a webpage.
#
# So far we have looked at how to get data from [in the Jupyter Notebook itself](https://github.com/pbeens/Data-Dunkers/blob/main/Demos/data-from-internal.ipynb) and from a [CSV file](https://github.com/pbeens/Data-Dunkers/blob/main/Demos/data-from-csv.ipynb).
#
# In this demo, we will demonstrate how to get data from an Excel file.

# %% [markdown]
# ## Data from an Excel spreadsheet

# %% [markdown]
# Importing the data from an Excel file isn't much different that from a CSV file. We simply substitute
#
# `df = pd.read_csv('x-y-data.csv')`
#
# with
#
# `df = pd.read_excel('x-y-data.xlsx')`
#
# Here's the program:

# %%
import plotly.express as px
import pandas as pd

# Read the Excel file into a DataFrame named df
url = 'https://raw.githubusercontent.com/Data-Dunkers/data-dunkers-modules/main/data-dunkers/Data/x-y-data.xlsx'
df = pd.read_excel(url)

# Create the plot
fig = px.line(data_frame=df, 
              x='X', 
              y='Y', 
              title='Data from an Excel file')

# Show the plot
fig.show()

# %% [markdown]
# ## Exercise

# %% [markdown]
# Using the code above as an example, use the data below to plot Pascal Siakam's field goals made over his Raptors career.

# %%
# Setup


# Input
url = 'https://raw.githubusercontent.com/Data-Dunkers/data-dunkers-modules/main/data-dunkers/Data/example.xls'


# Process


# Output

# %% [markdown]
# ---
# In our next demonstration we will get our data from a [webpage](data-from-webpage.ipynb).
#
# ---
# Back to [Lessons](../Lessons.ipynb)
