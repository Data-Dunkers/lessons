# %% [markdown]
# ![Data Dunkers Banner](https://github.com/Data-Dunkers/lessons/blob/main/images/top-banner.jpg?raw=true)
#
# <a href="https://hub.callysto.ca/jupyter/hub/user-redirect/git-pull?repo=https%3A%2F%2Fgithub.com%2Fdata-dunkers%2Flessons&branch=main&subPath=graphing-pie-charts.ipynb&depth=1" target="_parent"><img src="https://raw.githubusercontent.com/Data-Dunkers/lessons/main/images/open-in-callysto-button.svg?sanitize=true" width="123" height="24" alt="Open in Callysto"/></a>
# <a href="https://colab.research.google.com/github/data-dunkers/lessons/blob/main/graphing-pie-charts.ipynb" target="_parent"><img src="https://raw.githubusercontent.com/Data-Dunkers/lessons/main/images/open-in-colab-button.svg?sanitize=true" width="123" height="24" alt="Open in Colab"/></a>

# %% [markdown]
# # Data Dunkers Lesson: Creating Pie Charts

# %% [markdown]
# The corresponding Activity Notebook for this Lesson Notebook can be found [here](https://github.com/Data-Dunkers/activities/blob/main/graphing.ipynb).

# %% [markdown]
# ## Objectives

# %% [markdown]
# By the end of this lesson, students will be able to:
# - Use pie charts for visualizing data distributions. *(Example: Create a pie chart to represent Pascal Siakam's field goals made across different NBA seasons.)*
# - Customize pie charts to enhance data visualization. *(Example: Adjust the labels and colors in a pie chart to better represent the distribution of data.)*

# %% [markdown]
# ## Importing and Filtering Data

# %% [markdown]
# We will use the [code library](https://en.wikipedia.org/wiki/Library_(computing)) called [pandas](https://pandas.pydata.org/) to import data from a [CSV file](https://en.wikipedia.org/wiki/Comma-separated_values).

# %%
import pandas as pd
import plotly.express as px

url = 'https://raw.githubusercontent.com/Data-Dunkers/data/main/NBA/Pascal_Siakam.csv'
df = pd.read_csv(url)

df = df[df['SEASON_ID'] <= '2022-23']
df

# %% [markdown]
# ## Pie Charts

# %% [markdown]
# When creating a [pie chart](https://plotly.com/python/pie-charts/), we use `values=` and `names=` instead of `x=` and `y=`.

# %%
px.pie(df, values='FGM', names='SEASON_ID', title='Siakam Field Goals by Season')

# %% [markdown]
# ## Exercise

# %% [markdown]
# Create a pie chart of games played (`'GP'`) by season.

# %%
# write your code here

# %% [markdown]
# ---
# Back to [Lessons](https://github.com/Data-Dunkers/lessons/blob/main/lessons.ipynb)
